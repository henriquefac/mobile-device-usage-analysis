# %%
from src import utils
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd

dataset_dir = utils.get_dataset_dir()
csv_file: Path = dataset_dir.get_any("user_behavior_dataset.csv")

# %% [markdown]
# # Análise exploratória

# %%
# Explorar os dados e como eles se comportam

df = pd.read_csv(csv_file, )
df
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %%
# columns
columns = list(df.columns.values)
num_columns = columns.copy()
num_columns.pop(0)
num_columns.pop(0)
num_columns.pop(0)
num_columns.pop(-1)
num_columns.pop(-1)
num_columns
# Out:
# ['App Usage Time (min/day)',
#  'Screen On Time (hours/day)',
#  'Battery Drain (mAh/day)',
#  'Number of Apps Installed',
#  'Data Usage (MB/day)',
#  'Age']

# %%
display(df.head())
display(df.info())
display(df.describe())
display(df.isna().sum())
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
df["User Behavior Class"].value_counts().sort_index().plot(kind="bar")
plt.title("Distribuição das Classes de Usuário")
plt.xlabel("Classe")
plt.ylabel("Quantidade")
plt.show()

# %%
df[num_columns].hist(figsize=(12,10))
plt.tight_layout()
plt.show()
